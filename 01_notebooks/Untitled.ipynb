# %% [markdown]
# WormLib Tutorial

# %%
Open DV, ND2 or TIFF files


conda create -n WormLib
conda activate WormLib


We recommend you make a conda enironment to install all the dependencies listed in requirements.txt

To run WormLib locally recommend using WormLib jupyter notebook (WormLib.ipynb). Note this is for a single embryo at a time.

To run WormLib in batch we recommend loading the python script (WormLib.py) to your HPC system and run using the bash script (run_WormLib.sh).


#### 2.2 Organize image files for processing

experiment_name > input > 01, 02, 03…



#### 2.3 Specify settings:

1. Run data on Ce-bigfish (single embryo Jupyter notebook)
	a. Select single embryo for test
	-image file path
	-what Fps are you using, what is there Em wavelength
	-voxel size
	-NA
	-refractive index
